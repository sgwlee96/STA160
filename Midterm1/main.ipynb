# %%
import opendatasets as od
od.download("https://www.kaggle.com/datasets/shrutimehta/nasa-asteroids-classification?datasetId=14512&sortBy=voteCount")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username:Your Kaggle Key:Downloading nasa-asteroids-classification.zip to ./nasa-asteroids-classification
# 100%|██████████| 3.27M/3.27M [00:00<00:00, 12.3MB/s]

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
nasadf = pd.read_csv("/Users/sungwonLee/Documents/STA160/Midterm1/datasets/nasa.csv")
nasadf
# Out:
#       Neo Reference ID     Name  Absolute Magnitude  Est Dia in KM(min)  \
# 0              3703080  3703080              21.600            0.127220
# 1              3723955  3723955              21.300            0.146068
# 2              2446862  2446862              20.300            0.231502
# 3              3092506  3092506              27.400            0.008801
# 4              3514799  3514799              21.600            0.127220
# ...                ...      ...                 ...                 ...
# 4682           3759007  3759007              23.900            0.044112
# 4683           3759295  3759295              28.200            0.006089
# 4684           3759714  3759714              22.700            0.076658
# 4685           3759720  3759720              21.800            0.116026
# 4686           3772978  3772978              19.109            0.400641
#
#       Est Dia in KM(max)  Est Dia in M(min)  Est Dia in M(max)  \
# ...

# %%
nasadf.columns
# nasadf.columns["Miss Dist.(Astronomical)"]
nasadf.iloc[:, 16:21]
# Out:
#       Miss Dist.(Astronomical)  Miss Dist.(lunar)  Miss Dist.(kilometers)  \
# 0                     0.419483         163.178711            6.275369e+07
# 1                     0.383014         148.992630            5.729815e+07
# 2                     0.050956          19.821890            7.622912e+06
# 3                     0.285322         110.990387            4.268362e+07
# 4                     0.407832         158.646713            6.101082e+07
# ...                        ...                ...                     ...
# 4682                  0.041361          16.089413            6.187511e+06
# 4683                  0.006469           2.516399            9.677324e+05
# 4684                  0.061009          23.732393            9.126775e+06
# 4685                  0.260760         101.435493            3.900908e+07
# 4686                  0.462372         179.862671            6.916986e+07
#
#       Miss Dist.(miles) Orbiting Body
# 0          3.899334e+07         Earth
# ...

# %%
X = nasadf.iloc[:,2:-2]
y = nasadf["Hazardous"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 77)

# %%
from pycaret.classification import *

# %%
clf = setup(data = nasadf, target="Hazardous", session_id=123)
# Out:
# <style type="text/css">
# #T_41f06_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_41f06_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41f06_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_41f06_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_41f06_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_41f06_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_41f06_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_41f06_row1_col1" class="data row1 col1" >Hazardous</td>
#     </tr>
#     <tr>
#       <th id="T_41f06_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_41f06_row2_col0" class="data row2 col0" >Target Type</td>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_d4974_ th {
#   text-align: left;
# }
# ...

# %%
models()[models()['Turbo'] == True]
# Out:
#                                      Name  \
# ID
# lr                    Logistic Regression
# knn                K Neighbors Classifier
# nb                            Naive Bayes
# dt               Decision Tree Classifier
# svm                   SVM - Linear Kernel
# ridge                    Ridge Classifier
# rf               Random Forest Classifier
# qda       Quadratic Discriminant Analysis
# ada                  Ada Boost Classifier
# gbc          Gradient Boosting Classifier
# lda          Linear Discriminant Analysis
# et                 Extra Trees Classifier
# xgboost         Extreme Gradient Boosting
# lightgbm  Light Gradient Boosting Machine
# dummy                    Dummy Classifier
#
#                                                   Reference  Turbo
# ID
# lr        sklearn.linear_model._logistic.LogisticRegression   True
# knn       sklearn.neighbors._classification.KNeighborsCl...   True
# nb                           sklearn.naive_bayes.GaussianNB   True
# ...
